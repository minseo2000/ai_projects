# %% [markdown]
# # 국민청원 분류하기!

# %% [markdown]
# # 이번 파트에서 진행할 프로젝트는 딥러닝을 활용한 텍스트 분류 프로젝트이다.
# # 자연어 처리 : 텍스트를 모델링하는 분랴(Natural Language Processing, NLP)라고 합니다.
#
# # 자연어 처리에는 다양한 분야가 있으며, 1) 텍스트 분류(Text Classification), 2) 감정 분석(Sentiment Analysis), 3) 요약(Summarization)
# # 4) 기계 번역(Machine Translation) 5) 질문 응답(Question Answering) 등이 있습니다.
#
# # 이번 프로젝트에서는 이 중에서 텍스트 분류인 Text Classification에 해당하며 문장에 대한 정보를 활용해서 글을 분류합니다!

# %% [markdown]
# # 국민청원 글에 TextCNN이라는 모델을 적용하여 특정 글에서 청원 참여인원이 1000명 이상 달성할지 여부를 분류하는 것을 목표로합니다.
# ### 즉, 수많은 청원 글 중에 주목받을 만한 글을 예측하는 것이 목적입니다.
# ### 딥러닝 모델을 통해서, 참여인원이 높은 글들과의 유사성을 계산하여 주목받을 만한 글인지 아닌지를 판단하는 것을 목표로 합니다.

# %% [markdown]
# ![image.png](attachment:193074da-cb7e-4115-b2f9-7a61c6fe0027.png)
